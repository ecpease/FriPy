# %%
# Import Python libraries
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
import os

# %%
masterDF = pd.read_excel('Clearwater_SiteInformation.xlsx')
masterDF.dropna(subset=['Longitude', 'Latitude'],inplace=True)
masterDF
# Out:
#           StationNo                                           SiteName  \
# 0           8104300                            Salado Ck at Salado, TX
# 1   304940097413300  Salado Ck blw conf of N and S Salado Ck, Jarre...
# 2   304957097304301                                          Little D.
# 3   305150097334401                                        Eastland W.
# 4   305303097423601                                         Gault site
# 5   305310097420601                                    Salado Quarries
# 6   305400097380101                                           Micheaux
# 7   305406097461001                            Stillman Valley Monitor
# 8   305457097353601                                             FM2843
# 9   305509097310901                                              Capps
# 10  305517097343501                                              Owens
# 11  305541097361701                                             Peters
# 12  305552097322801                                       Bloomer Mfg.
# 13  305602097315201                                    Salado Cemetery
# 14  305624097321101                          Stagecoach Inn Hilltop #2
# 15  305631097321601                       Stagecoach Inn - "Cave" well
# 16  305633097323401                        Robertson servants quarters
# 17  305636097320801                                        Critchfield
# 18  305637097321201                                      Big  Boiling
# 19  305638097321401                                     Little Boiling
# 20  305639097320601                                           Benedict
# 21  305640097320201                                           Anderson
# 22  305640097323001                                       Robertson 2B
# 23  305650097354801                                             Coppin
# 24  305700097322701                                         Salado ISD
# 25  305716097335601                                     Tenroc Ranch 2
# 26  305718097314401                 Salado Water Supply Corporation #2
# 27  305723097334601                                     Tenroc Ranch 1
# 28  305759097305201                                           Bartlett
# 29  305827097284501                                             Thaler
# 30  305946097293901                               Broeker Funeral Home
# 31  310053097285601                                       Goode Towing
# 32  310056097263601                                              Stowe
# 33  310129097274701                                            Gifford
# 34  310639097490401                                           CTC well
# 35  310754097222401                                  City of Temple #2
#
#    SiteType   Latitude  Longitude           GeologicUnit  Aquifer  Label
# 0        SW  30.944300 -97.534100                     --       --      1
# 1        SW  30.827800 -97.692500                     --       --      2
# 2        GW  30.832476 -97.511911          Edwards Group  Edwards      3
# 3        GW  30.863793 -97.562271          Edwards Group  Edwards      4
# 4        GW  30.884233 -97.709950          Edwards Group  Edwards      5
# 5        GW  30.886049 -97.701580          Edwards Group  Edwards      6
# 6        GW  30.900000 -97.633600  Travis Peak Formation  Trinity      7
# 7        GW  30.901700 -97.769400         Hensell Member  Trinity      8
# 8        GW  30.915800 -97.593300          Edwards Group  Edwards      9
# 9        GW  30.919113 -97.519073          Edwards Group  Edwards     10
# 10       GW  30.921500 -97.576367          Edwards Group  Edwards     11
# 11       GW  30.928167 -97.604667          Edwards Group  Edwards     12
# 12       GW  30.931034 -97.541087          Edwards Group  Edwards     13
# 13       GW  30.933900 -97.531100          Edwards Group  Edwards     14
# 14       GW  30.940000 -97.536400          Edwards Group  Edwards     15
# 15       GW  30.941900 -97.537800          Edwards Group  Edwards     16
# 16       GW  30.942500 -97.542800          Edwards Group  Edwards     17
# 17       SP  30.943300 -97.535600          Edwards Group  Edwards     18
# 18       SP  30.943600 -97.536700          Edwards Group  Edwards     19
# 19       SP  30.943900 -97.537200          Edwards Group  Edwards     20
# 20       SP  30.944200 -97.535000          Edwards Group  Edwards     21
# 21       SP  30.944400 -97.533900          Edwards Group  Edwards     22
# 22       SP  30.944400 -97.541700          Edwards Group  Edwards     23
# 23       GW  30.947139 -97.596690          Edwards Group  Edwards     24
# 24       GW  30.950095 -97.540834          Edwards Group  Edwards     25
# 25       GW  30.954562 -97.565495          Edwards Group  Edwards     26
# 26       GW  30.955000 -97.528900          Edwards Group  Edwards     27
# 27       GW  30.956418 -97.562801          Edwards Group  Edwards     28
# 28       GW  30.966383 -97.514435          Edwards Group  Edwards     29
# 29       GW  30.974083 -97.479167          Edwards Group  Edwards     30
# 30       GW  30.995983 -97.494133          Edwards Group  Edwards     31
# 31       GW  31.014651 -97.482150          Edwards Group  Edwards     32
# 32       GW  31.015485 -97.443256          Edwards Group  Edwards     33
# 33       GW  31.024655 -97.463033          Edwards Group  Edwards     34
# 34       GW  31.110800 -97.817800    Glen Rose Formation  Trinity     35
# 35       GW  31.131700 -97.373300         Hosston Member  Trinity     36

# %%
masterDF['geometry'] = masterDF.apply(lambda xy: Point(xy['Longitude'],xy['Latitude']),axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ea8c98ee0c20> in <module>()
# ----> 1 masterDF['geometry'] = masterDF.apply(lambda xy: Point(xy['Longitude'],xy['Latitude']),axis=1)
#
# NameError: name 'masterDF' is not defined

# %%
masterDF = masterDF[['geometry', 'StationNo', 'SiteName', 'SiteType', 'WellNo', 'GeologicUnit', 'Aquifer']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8282ec465b7f> in <module>()
# ----> 1 masterDF = masterDF[['geometry', 'StationNo', 'SiteName', 'SiteType', 'WellNo', 'GeologicUnit', 'Aquifer']]
#
# NameError: name 'masterDF' is not defined

# %%
proj4 = '+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs'
masterDF = gpd.GeoDataFrame(masterDF,geometry='geometry' ,crs=proj4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3e77ff9adeac> in <module>()
#       1 proj4 = '+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs'
# ----> 2 masterDF = gpd.GeoDataFrame(masterDF,geometry='geometry' ,crs=proj4)
#
# NameError: name 'masterDF' is not defined

# %%
masterDF.to_file(os.path.join('shapefile', 'ClearwaterSites.shp'))
